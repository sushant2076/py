# %% [markdown]
# <a href="https://colab.research.google.com/github/sushant2076/py/blob/master/DLHC_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/VerataiLtd/snomed_graph.git
# Out:
# Cloning into 'snomed_graph'...
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 35 (delta 19), reused 24 (delta 8), pack-reused 0
# Receiving objects: 100% (35/35), 26.40 KiB | 458.00 KiB/s, done.
# Resolving deltas: 100% (19/19), done.

# %%
from pathlib import Path
import pandas as pd

# %%
def load_snomed_df(data_path):
    """
    Create a SNOMED CT concept DataFrame.

    Derived from: https://github.com/CogStack/MedCAT/blob/master/medcat/utils/preprocess_snomed.py

    Returns:
        pandas.DataFrame: SNOMED CT concept DataFrame.
    """

    def _read_file_and_subset_to_active(filename):
        with open(filename, encoding="utf-8") as f:
            entities = [[n.strip() for n in line.split("\t")] for line in f]
            df = pd.DataFrame(entities[1:], columns=entities[0])
        return df[df.active == "1"]

    active_terms = _read_file_and_subset_to_active(
        data_path / "sct2_Concept_Snapshot_INT_20230531.txt"
    )
    active_descs = _read_file_and_subset_to_active(
        data_path / "sct2_Description_Snapshot-en_INT_20230531.txt"
    )

    df = pd.merge(active_terms, active_descs, left_on=["id"], right_on=["conceptId"], how="inner")[
        ["id_x", "term", "typeId"]
    ].rename(columns={"id_x": "concept_id", "term": "concept_name", "typeId": "name_type"})

    # active description or active synonym
    df["name_type"] = df["name_type"].replace(
        ["900000000000003001", "900000000000013009"], ["P", "A"]
    )
    active_snomed_df = df[df.name_type.isin(["P", "A"])]

    active_snomed_df["hierarchy"] = active_snomed_df["concept_name"].str.extract(
        r"\((\w+\s?.?\s?\w+.?\w+.?\w+.?)\)$"
    )
    active_snomed_df = active_snomed_df[active_snomed_df.hierarchy.notnull()].reset_index(drop=True)
    return active_snomed_df

# %%
snomed_rf2_path = Path(
    "/content/drive/MyDrive/DLHC_Project/SnomedCT_InternationalRF2_PRODUCTION_20230531T120000Z_Challenge_Edition"
)

# %%
df = load_snomed_df(snomed_rf2_path / "Snapshot" / "Terminology")
df.shape[0]
# Out:
# 364323

# %%
concept_type_subset = [
    "procedure",                    # top level category
    "body structure",               # top level category
    "finding",                      # top level category
    "disorder",                     # child of finding
    "morphologic abnormality",      # child of body structure
    "regime/therapy",               # child of procedure
    "cell structure",               # child of body structure
]

# %%
filtered_df = df[
    (df.hierarchy.isin(concept_type_subset)) &   # Filter the SNOMED data to the selected Concept Types
    ( df.name_type == "P" )                      # Preferred Terms only (i.e. one row per concept, drop synonyms)
].copy()

# %%
filtered_df.shape[0]
# Out:
# 218467

# %%
filtered_df.hierarchy.value_counts()
# Out:
# disorder                   83431
# procedure                  55981
# finding                    35545
# body structure             34914
# morphologic abnormality     4969
# regime/therapy              3110
# cell structure               517
# Name: hierarchy, dtype: int64

# %%
filtered_df.drop("name_type", axis="columns", inplace=True)
filtered_df.to_csv("flattened_terminology.csv")

# %%
training_set = pd.read_csv("/content/drive/MyDrive/DLHC_Project/snomed-ct-entity-linking-challenge-1.0.0/mimic-iv_notes_training_set.csv")
training_annot = pd.read_csv("/content/drive/MyDrive/DLHC_Project/snomed-ct-entity-linking-challenge-1.0.0/train_annotations.csv")

# %%
#BiLSTM-CNN
#FLERT

# %%
len(training_set["text"][0])
# Out:
# 4279

# %%
training_set["text"][0]
# Out:
# ' \nName:  ___                  Unit No:   ___\n \nAdmission Date:  ___              Discharge Date:   ___\n \nDate of Birth:  ___             Sex:   M\n \nService: SURGERY\n \nAllergies: \nPenicillins\n \nAttending: ___.\n \nChief Complaint:\nBiliary pancreatitis\n \nMajor Surgical or Invasive Procedure:\n___: Laparoscopic cholecystectomy\n\n \nHistory of Present Illness:\nMr. ___ is a ___ man who had severe biliary \npancreatitis resulting in pancreatic necrosis for which he was \ntreated with nasojejunal feedings and pancreatic rest.  He had \ninitially had multisystem organ failure, which improved. Mr. \n___ has a large postnecrotic pseudocyst, which has been \ndrained through a minimally invasive approach into his GI tract. \n He has some debris, but this is not currently infected. The \npatient was followed by Dr. ___ in his ___ \nclinic to discuss cholecystectomy. After discussion of all \nrisks, benefits and possible outcomes, patient was scheduled for \nelective cholecystectomy on ___.\n \nPast Medical History:\nHiatal Hernia  \n___ esophagus  \nEsophageal ulcer  \nanxiety  \nBack pain \n \nSocial History:\n___\nFamily History:\nMother passed of metastatic lung cancer. Father alive, had CVA \nand MI.  No  history of pancreatic malignancy  \n\n \nPhysical Exam:\nPrior Discharge:\nVS: 98.3, 83, 137/69, 16, 98% RA\nGEN: NAD, AAO x 3\nCV: RRR\nPULM: CTAB\nABD: Laparoscopic incisions open to air with dermabond and c/d/i\nEXTR: Warm, +pp, no c/c/e\n \nPertinent Results:\nPathology: Pending\n \nBrief Hospital Course:\nThe patient with history of gallstone pancreatitis was admitted \nto the HPB Surgical Service on ___ after he underwent \nlaparoscopic cholecystectomy. After a brief, uneventful stay in \nthe PACU, the patient arrived on the floor tolerating regular \ndiet , on IV fluids, and Dilaudid PCA for pain control.  The \npatient was hemodynamically stable.\nPain was well controlled. Diet was tolerated well. The patient \nvoided without problem. The patient received subcutaneous \nheparin and venodyne boots were used during this stay.\nAt the time of discharge, the patient was doing well, afebrile \nwith stable vital signs. The patient was tolerating a regular \ndiet, ambulating, voiding without assistance, and pain was well \ncontrolled.  The patient was discharged home without services. \nThe patient received discharge teaching and follow-up \ninstructions with understanding verbalized and agreement with \nthe discharge plan.\n\n \nMedications on Admission:\nalprazolam 1", oxycodone 7.5mg prn, protonix 40\'\n \nDischarge Medications:\n1. ALPRAZolam 1 mg PO BID \n2. Docusate Sodium 100 mg PO BID \n3. HYDROmorphone (Dilaudid) ___ mg PO Q3H:PRN pain \nRX *hydromorphone [Dilaudid] 2 mg ___ tablet(s) by mouth Q3H \nDisp #*120 Tablet Refills:*0\n4. Pantoprazole 40 mg PO Q24H \n\n \nDischarge Disposition:\nHome\n \nDischarge Diagnosis:\nBiliary pancreatitis\n\n \nDischarge Condition:\nMental Status: Clear and coherent.\nLevel of Consciousness: Alert and interactive.\nActivity Status: Ambulatory - Independent.\n\n \nDischarge Instructions:\nYou were admitted to the surgery service at ___ for surgical \nresection of your gallbladder. You have done well in the post \noperative period and are now safe to return home to complete \nyour recovery with the following instructions:\n.\nCall Dr. ___ office at ___ if you have any \nquestions or concerns. During off hours: call Operator at \n___ and ask to ___ team.\n.\nPlease resume all regular home medications , unless specifically \nadvised not to take a particular medication.  Also, please take \nany new medications as prescribed.\nPlease get plenty of rest, continue to ambulate several times \nper day, and drink adequate amounts of fluids.  Avoid lifting \nweights greater than ___ lbs until you follow-up with your \nsurgeon, who will instruct you further regarding activity \nrestrictions.\nAvoid driving or operating heavy machinery while taking pain \nmedications.\nPlease follow-up  ...

# %%
filtered_df
# Out:
#                 concept_id                                       concept_name  \
# 3                   104001          Excision of lesion of patella (procedure)
# 4                   106004  Structure of posterior carpal region (body str...
# 5                   107008  Structure of fetal part of placenta (body stru...
# 6                   108003     Entire condylar emissary vein (body structure)
# 7                   109006  Anxiety disorder of childhood OR adolescence (...
# ...                    ...                                                ...
# 364312  971918681000119107  Chronic respiratory failure due to obstructive...
# 364313  972604701000119104  Acquired arteriovenous malformation of vascula...
# 364315  978253001000132109           Small bowel enteroscopy normal (finding)
# 364317  985355341000119101  Malignant melanoma of skin of left wrist (diso...
# 364318  987840791000119102        Adenosine deaminase 2 deficiency (disorder)
#
#              hierarchy
# 3            procedure
# 4       body structure
# 5       body structure
# 6       body structure
# 7             disorder
# ...                ...
# 364312        disorder
# 364313        disorder
# 364315         finding
# 364317        disorder
# 364318        disorder
#
# [218467 rows x 3 columns]

# %%
filtered_df.to_csv("tags.csv")

# %%
training_annot
# Out:
#               note_id  start   end  concept_id
# 0       10060142-DS-9    179   190    91936005
# 1       10060142-DS-9    228   248    95563007
# 2       10060142-DS-9    294   322    45595009
# 3       10060142-DS-9    390   411    95563007
# 4       10060142-DS-9    425   444     1835003
# ...               ...    ...   ...         ...
# 51569  19926965-DS-14   9216  9227    76948002
# 51570  19926965-DS-14   9257  9261    22253000
# 51571  19926965-DS-14   9298  9302    22253000
# 51572  19926965-DS-14   9318  9323   386661006
# 51573  19926965-DS-14   9391  9395    22253000
#
# [51574 rows x 4 columns]

# %%
training_set
# Out:
#             note_id                                               text
# 0     10060142-DS-9   \nName:  ___                  Unit No:   ___\...
# 1     10097089-DS-8   \nName:  ___                  Unit No:   ___\...
# 2     10124346-DS-4   \nName:  ___              Unit No:   ___\n \n...
# 3     10302979-DS-5   \nName:  ___                 Unit No:   ___\n...
# 4    10352433-DS-20   \nName:  ___                  Unit No:   ___\...
# ..              ...                                                ...
# 199  19859532-DS-19   \nName:  ___                   Unit No:   ___...
# 200  19871603-DS-14   \nName:  ___                  Unit No:   ___\...
# 201  19884924-DS-14   \nName:  ___                    Unit No:   __...
# 202   19895550-DS-7   \nName:  ___               Unit No:   ___\n \...
# 203  19926965-DS-14   \nName:  ___               Unit No:   ___\n \...
#
# [204 rows x 2 columns]

# %%
dataset_merged = pd.merge(training_annot, training_set, on='note_id', how='left')

# %%
dataset_merged
# Out:
#               note_id  start   end  concept_id  \
# 0       10060142-DS-9    179   190    91936005
# 1       10060142-DS-9    228   248    95563007
# 2       10060142-DS-9    294   322    45595009
# 3       10060142-DS-9    390   411    95563007
# 4       10060142-DS-9    425   444     1835003
# ...               ...    ...   ...         ...
# 51569  19926965-DS-14   9216  9227    76948002
# 51570  19926965-DS-14   9257  9261    22253000
# 51571  19926965-DS-14   9298  9302    22253000
# 51572  19926965-DS-14   9318  9323   386661006
# 51573  19926965-DS-14   9391  9395    22253000
#
#                                                     text
# 0       \nName:  ___                  Unit No:   ___\...
# 1       \nName:  ___                  Unit No:   ___\...
# 2       \nName:  ___                  Unit No:   ___\...
# 3       \nName:  ___                  Unit No:   ___\...
# 4       \nName:  ___                  Unit No:   ___\...
# ...                                                  ...
# 51569   \nName:  ___               Unit No:   ___\n \...
# 51570   \nName:  ___               Unit No:   ___\n \...
# 51571   \nName:  ___               Unit No:   ___\n \...
# 51572   \nName:  ___               Unit No:   ___\n \...
# 51573   \nName:  ___               Unit No:   ___\n \...
#
# [51574 rows x 5 columns]

# %%
filtered_df['concept_id'] = pd.to_numeric(filtered_df['concept_id'])

# %%
dataset_train = pd.merge(dataset_merged, filtered_df, on="concept_id", how="left")

# %%
dataset_train
# Out:
#               note_id  start   end  concept_id  \
# 0       10060142-DS-9    179   190    91936005
# 1       10060142-DS-9    228   248    95563007
# 2       10060142-DS-9    294   322    45595009
# 3       10060142-DS-9    390   411    95563007
# 4       10060142-DS-9    425   444     1835003
# ...               ...    ...   ...         ...
# 51569  19926965-DS-14   9216  9227    76948002
# 51570  19926965-DS-14   9257  9261    22253000
# 51571  19926965-DS-14   9298  9302    22253000
# 51572  19926965-DS-14   9318  9323   386661006
# 51573  19926965-DS-14   9391  9395    22253000
#
#                                                     text  \
# 0       \nName:  ___                  Unit No:   ___\...
# 1       \nName:  ___                  Unit No:   ___\...
# 2       \nName:  ___                  Unit No:   ___\...
# 3       \nName:  ___                  Unit No:   ___\...
# 4       \nName:  ___                  Unit No:   ___\...
# ...                                                  ...
# 51569   \nName:  ___               Unit No:   ___\n \...
# 51570   \nName:  ___               Unit No:   ___\n \...
# 51571   \nName:  ___               Unit No:   ___\n \...
# 51572   \nName:  ___               Unit No:   ___\n \...
# 51573   \nName:  ___               Unit No:   ___\n \...
#
#                                    concept_name  hierarchy
# 0               Allergy to penicillin (finding)    finding
# 1             Gallstone pancreatitis (disorder)   disorder
# 2      Laparoscopic cholecystectomy (procedure)  procedure
# 3             Gallstone pancreatitis (disorder)   disorder
# 4               Necrosis of pancreas (disorder)   disorder
# ...                                         ...        ...
# 51569                     Severe pain (finding)    finding
# 51570                            Pain (finding)    finding
# 51571                            Pain (finding)    finding
# 51572                           Fever (finding)    finding
# 51573                            Pain (finding)    finding
#
# [51574 rows x 7 columns]

# %%
for row in range(len(dataset_train["text"])):
  for j in range(len(dataset_train["text"][row])):
    if(dataset_train["text"][row][j]=='S' and dataset_train["text"][row][j+2]=='r'):
      dataset_train["text"][row]= dataset_train["text"][row][j:]
      dataset_train["start"][row]-=j
      dataset_train["end"][row]-=j
      break
# Out:
# <ipython-input-24-5a22182d16a8>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_train["text"][row]= dataset_train["text"][row][j:]
# <ipython-input-24-5a22182d16a8>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_train["start"][row]-=j
# <ipython-input-24-5a22182d16a8>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_train["end"][row]-=j

# %%
dataset_train
# Out:
#               note_id  start   end  concept_id  \
# 0       10060142-DS-9     31    42    91936005
# 1       10060142-DS-9     80   100    95563007
# 2       10060142-DS-9    146   174    45595009
# 3       10060142-DS-9    242   263    95563007
# 4       10060142-DS-9    277   296     1835003
# ...               ...    ...   ...         ...
# 51569  19926965-DS-14   9071  9082    76948002
# 51570  19926965-DS-14   9112  9116    22253000
# 51571  19926965-DS-14   9153  9157    22253000
# 51572  19926965-DS-14   9173  9178   386661006
# 51573  19926965-DS-14   9246  9250    22253000
#
#                                                     text  \
# 0      Service: SURGERY\n \nAllergies: \nPenicillins\...
# 1      Service: SURGERY\n \nAllergies: \nPenicillins\...
# 2      Service: SURGERY\n \nAllergies: \nPenicillins\...
# 3      Service: SURGERY\n \nAllergies: \nPenicillins\...
# 4      Service: SURGERY\n \nAllergies: \nPenicillins\...
# ...                                                  ...
# 51569  Service: SURGERY\n \nAllergies: \npenicillin G...
# 51570  Service: SURGERY\n \nAllergies: \npenicillin G...
# 51571  Service: SURGERY\n \nAllergies: \npenicillin G...
# 51572  Service: SURGERY\n \nAllergies: \npenicillin G...
# 51573  Service: SURGERY\n \nAllergies: \npenicillin G...
#
#                                    concept_name  hierarchy
# 0               Allergy to penicillin (finding)    finding
# 1             Gallstone pancreatitis (disorder)   disorder
# 2      Laparoscopic cholecystectomy (procedure)  procedure
# 3             Gallstone pancreatitis (disorder)   disorder
# 4               Necrosis of pancreas (disorder)   disorder
# ...                                         ...        ...
# 51569                     Severe pain (finding)    finding
# 51570                            Pain (finding)    finding
# 51571                            Pain (finding)    finding
# 51572                           Fever (finding)    finding
# 51573                            Pain (finding)    finding
#
# [51574 rows x 7 columns]

# %%
l =[]
for row in (dataset_train["note_id"]):
  l.append(row)

# %%
len(set(l))
# Out:
# 204

# %%
dataset_train_ = dataset_train.copy()

# %%
annotation = []
filters = ["!", "#", "$", "%", "&", "(", ")", "/", "*", ".", ":", ";", "<", "=", ">", "?", "@", "[",
               "\\", "]", "_", "`", "{", "}", "~", "'"]

for i in range(len(dataset_train[["start", "end", "text", "concept_name"]])):
  s = dataset_train["start"][i]
  e = dataset_train["end"][i]
  t = dataset_train["text"][i]
  c = dataset_train["concept_name"][i]
  text = dataset_train["text"][i][s:e]
  # dataset_train["text"][i] = dataset_train["text"][i].replace('_', '')
  # dataset_train["text"][i] = dataset_train["text"][i].replace('=', '')
  # dataset_train["text"][i] = ' '.join(dataset_train["text"][i].split())
  text = text.replace('\n', '')
  for j in filters:
    if j in text:
      text = text.replace(j, " " + j + " ")

  # text = text.replace('_', '')
  # text = text.replace('=', '')
  # text = ' '.join(text.split())

  tup = (text, c)
  annotation.append(tup)

# %%
dataset_train['annotations'] = annotation

# %%
dataset = dataset_train[["text", "annotations"]]

# %%
dataset_row_merged = dataset.groupby('text')["annotations"].agg(list).reset_index()

# %%
dataset_row_merged["annotations"][1]
# Out:
# [('Codeine', 'Allergy to codeine (finding)'),
#  ('adhesive tape', 'Allergy to adhesive agent (finding)'),
#  ('chest pain', 'Chest pain (finding)'),
#  ('fatigue', 'Fatigue (finding)'),
#  ('Coronary Artery Bypass Grafting x 2',
#   'Coronary artery bypass grafts x 2 (procedure)'),
#  ('left internal mammary artery',
#   'Structure of left internal thoracic artery (body structure)'),
#  ('left anterior descending coronary artery',
#   'Structure of anterior descending branch of left coronary artery (body structure)'),
#  ('saphenous vein graft',
#   'Aortocoronary artery bypass of one coronary artery with saphenous vein graft (procedure)'),
#  ('obtuse marginal',
#   'Structure of obtuse marginal branch of circumflex branch of left coronary artery (body structure)'),
#  ('cardiac risk factors',
#   'Assessment for risk of cardiovascular disease (procedure)'),
#  ('chest pain', 'Chest pain (finding)'),
#  ('angina', 'Angina (disorder)'),
#  ('Stress test', 'Electrocardiogram with exercise test (procedure)'),
#  ('anteroseptal ischemia',
#   'Ischemia of myocardium of anteroseptal region (disorder)'),
#  ('cardiac catheterization', 'Cardiac catheterization (procedure)'),
#  ('left main', 'Left coronary artery structure (body structure)'),
#  ('lesion', 'Lesion (morphologic abnormality)'),
#  ('SVT', 'Supraventricular tachycardia (disorder)'),
#  ('palpitations', 'Palpitations (finding)'),
#  ('diaphoresis', 'Excessive sweating (finding)'),
#  ('chest pain', 'Chest pain (finding)'),
#  ('surgical', 'Surgical procedure (procedure)'),
#  ('revascularization', 'Heart revascularization (procedure)'),
#  ('Hypertension', 'Hypertensive disorder, systemic arterial (disorder)'),
#  ('Dyslipidemia', 'Dyslipidemia (disorder)'),
#  ('Type II Diabetes Mellitus', 'Diabetes mellitus type 2 (disorder)'),
#  ('SVT', 'Supraventricular tachycardia (disorder)'),
#  ('Abdominal Aortic Aneurysm', 'Abdominal aortic aneurysm (disorder)'),
#  ('cath', 'Cardiac catheterization (procedure)'),
#  ('Cholecystectomy', 'Cholecystectomy (procedure)'),
#  ('Appendectomy', 'Excision of appendix (procedure)'),
#  ('died', 'Dead (finding)'),
#  ('myocardial infarction', 'Myocardial infarction (disorder)'),
#  ('HR', 'Finding of heart rate (finding)'),
#  ('BP', 'Blood pressure finding (finding)'),
#  ('RR', 'Finding of rate of respiration (finding)'),
#  ('O2 sat', 'Oxygen saturation measurement (procedure)'),
#  ('RA', 'Breathing room air (finding)'),
#  ('Height', 'Height / growth finding (finding)'),
#  ('Weight', 'Weight finding (finding)'),
#  ('General', 'General examination of patient (procedure)'),
#  ('distress', 'Distress (finding)'),
#  ('Skin', 'Examination of skin (procedure)'),
#  ('Warm', 'Warm skin (finding)'),
#  ('Intact', 'Intact skin (finding)'),
#  ('HEENT', 'Physical examination procedure (procedure)'),
#  ('NC', 'Normal head (finding)'),
#  ('PERRLA', 'Pupils equal, react to light and accommodation (finding)'),
#  ('EOMI', 'Normal ocular motility (finding)'),
#  ('Neck', 'Physical examination procedure (procedure)'),
#  ('Supple', 'Normal movement of neck (finding)'),
#  ('Full ROM', 'Normal range of cervical spine movement (finding)'),
#  ('JVD', 'Jugular venous engorgement (finding)'),
#  ('Chest', 'Examination of respiratory system (procedure)'),
#  ('Lungs', 'Examination of respiratory system (procedure)'),
#  ('Heart', 'Cardiovascular physical examination (procedure)'),
#  ('RRR', 'Normal heart rate (finding)'),
#  ('murmur', 'Murmur (finding)'),
#  ('rub', 'Pleural friction rub (finding)'),
#  ('Gallop', 'Gallop rhythm (finding)'),
#  ('Abdomen', 'Examination of abdomen (procedure)'),
#  ('Soft', 'Abdomen soft (finding)'),
#  ('non-distended', 'Normal abdominal contour (finding)'),
#  ('non-tender', 'Abdominal tenderness (finding)'),
#  ('bowel sounds', 'Normal bowel sounds (finding)'),
#  ('Extremities', 'Examination of limb (procedure)'),
#  ('Warm', 'Warm skin (finding)'),
#  ('well-perfused', 'Normal tissue perfusion (finding)'),
#  ('Edema', 'Edema (finding)'),
#  ('rash', 'Eruption of skin (disorder)'),
#  ('forearms', 'Forearm structure (body structure)'),
#  ('Varicosities', 'Venous varices (disorder)'),
#  ('Neuro', 'Neurological examination (procedure)'),
#  ('Grossly intact', 'Normal nervous system function (finding)'),
#  ('Femoral', 'Structure of femoral artery (body structure)'),
#  ('Right :  2+', 'Pulse present in right femoral artery (finding)'),
#  ('Left :  2+', 'Pulse present in left femoral artery (finding)'),
#  ('DP', 'Structure of dorsalis pedis artery (body structure)'),
#  ('Right :  2', 'Pulse present in right dorsalis pedis artery (finding)'),
#  ('Left :  2+', 'Pulse present in left dorsalis pedis artery (finding)'),
#  ('Right :  2', 'Normal pulse in right dorsalis pedis artery (finding)'),
#  ('Left :  2', 'Pulse present in left femoral artery (finding)'),
#  ('Radial', 'Structure of radial artery (body structure)'),
#  ('Right', 'Structure of right radial artery (body structure)'),
#  ('Left', 'Structure of left radial artery (body structure)'),
#  ('Carotid Bruit', 'Carotid bruit (finding)'),
#  ('Right', 'Structure of right carotid artery (body structure)'),
#  ('Left', 'Structure of left carotid artery (body structure)'),
#  ('VS', 'Vital signs finding (finding)'),
#  ('RA', 'Breathing room air (finding)'),
#  ('preop', 'Preoperative state (finding)'),
#  ('General', 'General examination of patient (procedure)'),
#  ('distress', 'Distress (finding)'),
#  ('HEENT', 'Physical examination procedure (procedure)'),
#  ('normocephalic', 'Normal head (finding)'),
#  ('Card', 'Structure of cardiovascular system (body structure)'),
#  ('RRR', 'Normal heart rate (finding)'),
#  ('normal S1,S2', 'Heart sounds normal (finding)'),
#  ('murmur', 'Murmur (finding)'),
#  ('Resp', 'Examination of respiratory system (procedure)'),
#  ('clear breath sounds', 'Normal breath sounds (finding)'),
#  ('GI', 'Examination of digestive system (procedure)'),
#  ('Extr', 'Examination of limb (procedure)'),
#  ('warm', 'Warm skin (finding)'),
#  ('edema', 'Edema (finding)'),
#  ('sternal', 'Sternal skin structure (body structure)'),
#  ('RLE', 'Skin structure of right lower limb (body structure)'),
#  ('clean dry intact', 'Wound healing well (finding)'),
#  ('erythema', 'Erythema (finding)'),
#  ('sternum', 'Sternal skin structure (body structure)'),
#  ('Neuro', 'Neurological examination (procedure)'),
#  ('awake', 'Awake (finding)'),
#  ('alert', 'Mentally alert (finding)'),
#  ('oriented', 'Orientated (finding)'),
#  ('ambulating', 'Fully mobile (finding)'),
#  ('Cardiac Catheterization', 'Cardiac catheterization (procedure)'),
#  ('Right dominant system', 'Right dominant coronary system (disorder)'),
#  ('Left main coronary artery',
#   'Structure of left coronary artery main stem (body structure)'),
#  ('stenosis', 'Stenosis (morphologic abnormality)'),
#  ('Left anterior descending',
#   'Structure of anterior descending branch of left coronary artery (body structure)'),
#  ('left circumflex arteries',
#   'Structure of circumflex branch of left coronary artery (body structure)'),
#  ('disease', 'Disease (disorder)'),
#  ('right coronary artery had proximal',
#   'Structure of proximal portion of right coronary artery (body structure)'),
#  ('lesion', 'Lesion (morphologic abnormality)'),
#  ('Abdominal aortogram', 'Abdominal aortogram (procedure)'),
#  ('aneurysm', 'Aneurysm (morphologic abnormality)'),
#  ('WBC', 'White blood cell count (procedure)'),
#  ('RBC', 'Red blood cell count (procedure)'),
#  ('Hgb', 'Measurement of total hemoglobin concentration (procedure)'),
#  ('Hct', 'Hematocrit determination (procedure)'),
#  ('MCV', 'Erythrocyte mean corpuscular volume determination (procedure)'),
#  ('MCH', 'Mean corpuscular hemoglobin determination (procedure)'),
#  ('RDW', 'Red cell distribution width determination (procedure)'),
#  ('WBC', 'White blood cell count (procedure)'),
#  ('RBC', 'Red blood cell count (procedure)'),
#  ('Hgb', 'Measurement of total hemoglobin concentration (procedure)'),
#  ('Hct', 'Hematocrit determination (procedure)'),
#  ('MCV', 'Erythrocyte mean corpuscular volume determination (procedure)'),
#  ('MCHC',
#   'Mean corpuscular hemoglobin concentration determination (procedure)'),
#  ('RDW', 'Red cell distribution width determination (procedure)'),
#  ('Glucose', 'Glucose measurement, blood (procedure)'),
#  ('UreaN', 'Blood urea nitrogen measurement (procedure)'),
#  ('Creat', 'Creatinine measurement (procedure)'),
#  ('Na', 'Blood sodium measurement (procedure)'),
#  ('K', 'Blood potassium measurement (procedure)'),
#  ('Cl', 'Chloride measurement, blood (procedure)'),
#  ('Glucose', 'Glucose measurement, blood (procedure)'),
#  ('UreaN', 'Blood urea nitrogen measurement (procedure)'),
#  ('Creat', 'Creatinine measurement (procedure)'),
#  ('Na', 'Blood sodium measurement (procedure)'),
#  ('K', 'Blood potassium measurement (procedure)'),
#  ('Cl', 'Chloride measurement, blood (procedure)'),
#  ('Glucose', 'Glucose measurement, blood (procedure)'),
#  ('UreaN', 'Blood urea nitrogen measurement (procedure)'),
#  ('Creat', 'Creatinine measurement (procedure)'),
#  ('Na', 'Blood sodium measurement (procedure)'),
#  ('K', 'Blood potassium measurement (procedure)'),
#  ('Cl', 'Chloride measurement, blood (procedure)'),
#  ('UreaN', 'Blood urea nitrogen measurement (procedure)'),
#  ('Creat', 'Creatinine measurement (procedure)'),
#  ('Na', 'Blood sodium measurement (procedure)'),
#  ('K', 'Blood potassium measurement (procedure)'),
#  ('Cl', 'Chloride measurement, blood (procedure)'),
#  ('HCO3', 'Blood bicarbonate measurement (procedure)'),
#  ('Mg', 'Blood magnesium measurement (procedure)'),
#  ('Hgb', 'Measurement of total hemoglobin concentration (procedure)'),
#  ('MRSA SCREEN',
#   'Multi-resistant staphylococcus aureus screening (procedure)'),
#  ('MRSA', 'Methicillin resistant Staphylococcus aureus infection (disorder)'),
#  ('Chest X-Ray', 'Plain chest X-ray (procedure)'),
#  ('atelectasis', 'Atelectasis (disorder)'),
#  ('left', 'Left lung structure (body structure)'),
#  ('right', 'Right lung structure (body structure)'),
#  ('left', 'Structure of left pleural cavity (body structure)'),
#  ('pleural effusion', 'Pleural effusion (disorder)'),
#  ('sternal', 'Structure of sternal region (body structure)'),
#  ('pulmonary edema', 'Pulmonary edema (disorder)'),
#  ('pneumothorax', 'Pneumothorax (disorder)'),
#  ('Coronary Artery Bypass Grafting x 2',
#   'Coronary artery bypass grafts x 2 (procedure)'),
#  ('left internal mammary artery',
#   'Structure of left internal thoracic artery (body structure)'),
#  ('left anterior descending coronary artery',
#   'Structure of anterior descending branch of left coronary artery (body structure)'),
#  ('saphenous vein graft',
#   'Aortocoronary artery bypass of one coronary artery with saphenous vein graft (procedure)'),
#  ('obtuse marginal',
#   'Structure of obtuse marginal branch of circumflex branch of left coronary artery (body structure)'),
#  ('procedure', 'Surgical procedure (procedure)'),
#  ('post-operatively', 'Postoperative state (finding)'),
#  ('stable condition', "Patient's condition stable (finding)"),
#  ('monitoring', 'Monitoring procedure (regime/therapy)'),
#  ('sedation', 'Administration of sedative (procedure)'),
#  ('neurologically intact', 'Normal nervous system function (finding)'),
#  ('extubated', 'Removal of endotracheal tube (procedure)'),
#  ('vasopressor support', 'Vasopressor therapy (procedure)'),
#  ('hemodynamically stable', 'Hemodynamically stable (finding)'),
#  ('telemetry', 'Cardiac telemetry (regime/therapy)'),
#  ('Chest tubes', 'Insertion of pleural tube drain (procedure)'),
#  ('pulmonary toilet', 'Airway toilet (procedure)'),
#  ('sinus rhythm', 'Sinus rhythm (finding)'),
#  ('Blood pressure', 'Blood pressure finding (finding)'),
#  ('restarted', 'Restart of medication (procedure)'),
#  ('Aspirin', 'Administration of aspirin (procedure)'),
#  ('bowel', 'Intestinal structure (body structure)'),
#  ('renal function', 'Renal function monitoring (regime/therapy)'),
#  ('diuresed', 'Diuretic therapy (procedure)'),
#  ('preop', 'Preoperative state (finding)'),
#  ('weight', 'Weight finding (finding)'),
#  ('Hyponatremia', 'Hyponatremia (finding)'),
#  ('asymptomatic', 'Asymptomatic (finding)'),
#  ('sliding scale', 'Sliding scale insulin regime (regime/therapy)'),
#  ('blood sugar', 'Blood sugar management (procedure)'),
#  ('evaluated', 'Evaluation procedure (procedure)'),
#  ('physical therapy', 'Physical therapy assessment (procedure)'),
#  ('ambulating', 'Fully mobile (finding)'),
#  ('wound was healing', 'Wound healing well (finding)'),
#  ('pain was controlled with oral analgesics',
#   'Demonstrates adequate pain control (finding)'),
#  ('good', "Patient's condition satisfactory (finding)"),
#  ('instructions', 'Recommendation to (procedure)'),
#  ('Home With Service', 'Home health aide service management (procedure)'),
#  ('Coronary Artery Disease', 'Coronary arteriosclerosis (disorder)'),
#  ('Hypertension', 'Hypertensive disorder, systemic arterial (disorder)'),
#  ('Hyperlipidemia', 'Hyperlipidemia (disorder)'),
#  ('Type II Diabetes Mellitus', 'Diabetes mellitus type 2 (disorder)'),
#  ('SVT', 'Supraventricular tachycardia (disorder)'),
#  ('Alert', 'Mentally alert (finding)'),
#  ('oriented x3', 'Oriented to person, time and place (finding)'),
#  ('Ambulating', 'Fully mobile (finding)'),
#  ('gait steady', 'Gait normal (finding)'),
#  ('Sternal pain', 'Pain of sternum (finding)'),
#  ('oral analgesics', 'Administration of analgesic (procedure)'),
#  ('Sternal Incision', 'Wound of structure of sternal region (disorder)'),
#  ('healing well', 'Wound healing well (finding)'),
#  ('erythema', 'Erythema (finding)'),
#  ('drainage', 'Wound discharge (finding)'),
#  ('shower', 'Functional activity education (procedure)'),
#  ('incisions', 'Surgical incision wound (morphologic abnormality)'),
#  ('incisions', 'Surgical incision wound (morphologic abnormality)'),
#  ('incisions', 'Surgical incision wound (morphologic abnormality)'),
#  ('temperature', 'Body temperature finding (finding)'),
#  ('while taking narcotics', 'Narcotherapy (procedure)'),
#  ('No lifting', 'Functional activity education (procedure)'),
#  ('sternal incision', 'Wound of structure of sternal region (disorder)')]

# %%
for i in range(len(dataset_row_merged)):
  dataset_row_merged["text"][i] = dataset_row_merged["text"][i].replace('\n', '')
  for j in filters:
    if j in dataset_row_merged["text"][i]:
      dataset_row_merged["text"][i] = dataset_row_merged["text"][i].replace(j, " " + j + " ")

# %%
dataset_row_merged["text"][1]
# Out:
# "Service :  CARDIOTHORACIC Allergies :  Codeine  /  adhesive tape  /  Percocet Attending :   _  _  _  .  Chief Complaint : Recurrent chest pain, fatigue Major Surgical or Invasive Procedure : Coronary Artery Bypass Grafting x 2  ( left internal mammary artery to the left anterior descending coronary artery ;  saphenous vein graft to the obtuse marginal branch )  History of Present Illness : Mrs .   _  _  _  is a  _  _  _  year old female with multiple cardiac risk factors whopresented with recurrent chest pain concerning for angina .  Stress test was notable for mild anteroseptal ischemia .  Subsequent cardiac catheterization showed 60 %  left main lesion .  Of note, she has history of SVT .  She reportedoccasional episodes of palpitations and diaphoresis sometimes associated with chest pain .  These episodes occurred several times per week .   Based upon the above findings, she was referred to Dr .   _  _  _  surgical revascularization .  Past Medical History : 1 .   Hypertension2 .   Dyslipidemia3 .   Type II Diabetes Mellitus4 .   History of SVT5 .   Abdominal Aortic Aneurysm - incidental finding on cathPast Surgical History :  1 .   s / p Open Cholecystectomy2 .   s / p Appendectomy Social History :  _  _  _ Family History : Father - died of myocardial infarction in his  _  _  _  Physical Exam : HR :  77  BP :  133 / 77  RR :  16  O2 sat :  99 %  RAHeight :  61 inches    Weight :  145 lbsGeneral :  Well-developed female in no acute distressSkin :  Warm  [ X ]  Dry  [ X ]  Intact  [ X ] HEENT :  NCAT  [ X ]  PERRLA  [ X ]  EOMI  [ X ] Neck :  Supple  [ X ]  Full ROM  [ X ]  JVD  [  ] Chest :  Lungs clear bilaterally  [ X ] Heart :  RRR  [ X ] , No murmur / rub / GallopAbdomen :  Soft  [ X ]  non-distended  [ X ]  non-tender  [ X ]  bowel sounds +  [ X ] Extremities :  Warm  [ X ] , well-perfused  [ X ]  Edema -, Slight rash on bilateral forearms .  Varicosities :  None  [ X ] Neuro :  Grossly intact  [ X ] Pulses : Femoral      Right :  2+  Left :  2+DP           Right :  2+  Left :  2+ _  _  _            Right :  2+  Left :  2+Radial       Right :  2+  Left :  2+Discharge Exam : Carotid Bruit    Right :  -   Left :  -Discharge Exam : VS :  T :  98 . 3  HR :  80-90 ' s SR  BP :  98-111 / 60  Sats :  96 %  RA  WT :  65 Kg preop 65 . 7 KgGeneral :   _  _  _  year-old female in no apparent distressHEENT :  normocephalicCard :  RRR normal S1,S2 no murmurResp :  clear breath sounds throughoutGI :  benignExtr :  warm no edemaWound :  sternal and RLE clean dry intact no erythema .  sternum stableNeuro :  awake, alert oriented .  ambulating in halls Pertinent Results : Cardiac CatheterizationRight dominant system .   Left main coronary artery with ostial 60 %  stenosis .  Left anterior descending and left circumflex arteries had no aniographically apparent coronary artery disease .  The right coronary artery had proximal 30 %  lesion .  Estimated LVEF was 60 %  .  Abdominal aortogram showed distal aneurysm . Labs :  _  _  _  WBC-7 . 1 RBC-3 . 11 *  Hgb-9 . 5 *  Hct-27 . 8 *  MCV-90 MCH-30 . 5 MCHC-34 . 0 RDW-12 . 8 Plt  _  _  _  _  _  _  WBC-7 . 6 #  RBC-3 . 29 *  #  Hgb-10 . 2 *  #  Hct-28 . 6 *  #  MCV-87 MCH-30 . 9 MCHC-35 . 5 *  RDW-12 . 8 Plt  _  _  _  _  _  _  Glucose-158 *  UreaN-12 Creat-0 . 6 Na-129 *  K-4 . 2 Cl-91 *  HCO3-34 _  _  _  Glucose-128 *  UreaN-11 Creat-0 . 5 Na-127 *  K-4 . 1 Cl-90 *  HCO3-33 _  _  _  Glucose-148 *  UreaN-10 Creat-0 . 6 Na-130 *  K-4 . 1 Cl-92 *  HCO3-29  _  _  _  UreaN-9 Creat-0 . 4 Na-137 K-3 . 3 Cl-108 HCO3-23  _  _  _  Mg-1 . 9 _  _  _  Hgb-8 . 7 *  calcHCT-26 _  _  _  MRSA SCREEN  ( Final  _  _  _  :     No MRSA isolated .  Chest X-Ray  _  _  _  :  There is evidence of bilateral basal atelectasis, left more than right .   In addition, a minimal left pleural effusion cannot be excluded .   The sternal wires and the postoperative clips are in unchanged position .   No overt pulmonary edema .   No pneumothorax .   Brief Hospital Course : She was admitted to  _  _  _  on  _  _  _  and was tak ...

# %%
dataset_row_merged.to_csv('df.csv')

# %%
import pandas as pd
import numpy as np

# %%
# dataset_row_merged = pd.read_csv("df.csv")

# %%
dataset_row_merged["annotations"][0]
# Out:
# [('Codeine', 'Allergy to codeine (finding)'),
#  ('Quinine', 'Allergy to quinine (finding)'),
#  ('non-small cell lung cancer', 'Non-small cell lung cancer (disorder)'),
#  ('cervical mediastinoscopy', 'Cervical mediastinoscopy (procedure)'),
#  ('flexible bronchoscopy', 'Flexible bronchoscopy (procedure)'),
#  ('smoker', 'Smoker (finding)'),
#  ('Hep C', 'Viral hepatitis type C (disorder)'),
#  ('HCC', 'Liver cell carcinoma (disorder)'),
#  ('liver transplant', 'Transplantation of liver (procedure)'),
#  ('RUL', 'Structure of upper lobe of right lung (body structure)'),
#  ('PET', 'Positron emission tomography (procedure)'),
#  ('nodule', 'Nodule (morphologic abnormality)'),
#  ('non-small cell carcinoma',
#   'Non-small cell carcinoma (morphologic abnormality)'),
#  ('asymptomatic', 'Asymptomatic (finding)'),
#  ('SOB', 'Dyspnea (finding)'),
#  ('cough', 'Cough (finding)'),
#  ('fevers', 'Fever (finding)'),
#  ('chills', 'Chill (finding)'),
#  ('nightsweats', 'Night sweats (finding)'),
#  ('biopsied', 'Biopsy (procedure)'),
#  ('lesion', 'Lesion (morphologic abnormality)'),
#  ('non-small cell carcinoma',
#   'Non-small cell carcinoma (morphologic abnormality)'),
#  ('Lymph nodes', 'Structure of lymph node (body structure)'),
#  ('biopsied', 'Biopsy (procedure)'),
#  ('PET', 'Positron emission tomography (procedure)'),
#  ('distant metastasis', 'Distant metastasis present (finding)'),
#  ('HEPATITIS C', 'Viral hepatitis type C (disorder)'),
#  ('genotype', 'Genotype determination (procedure)'),
#  ('no sequelae', 'Sequelae of disorders (disorder)'),
#  ('chronic liver disease', 'Chronic liver disease (disorder)'),
#  ('fibrosis', 'Fibrosis of lung (disorder)'),
#  ('biopsy', 'Biopsy (procedure)'),
#  ('liver transplant', 'Transplantation of liver (procedure)'),
#  ('HEPATOCELLULAR CARCINOMA',
#   'Hepatocellular carcinoma (morphologic abnormality)'),
#  ('RFA', 'Radiofrequency ablation (procedure)'),
#  ('lesion', 'Lesion (morphologic abnormality)'),
#  ('liver transplant', 'Transplantation of liver (procedure)'),
#  ('HYPERTENSION', 'Hypertensive disorder, systemic arterial (disorder)'),
#  ('LUNG NODULE', 'Nodule of lung (disorder)'),
#  ('DIABETES MELLITUS', 'Diabetes mellitus (disorder)'),
#  ('ALCOHOL ABUSE', 'Alcohol abuse (disorder)'),
#  ('DRUG ABUSE', 'Drug abuse (disorder)'),
#  ('stomach cancer', 'Malignant tumor of stomach (disorder)'),
#  ('diabetes', 'Diabetes mellitus (disorder)'),
#  ('alcoholic', 'Problem drinker (finding)'),
#  ('diabetes', 'Diabetes mellitus (disorder)'),
#  ('coronary artery disease', 'Coronary arteriosclerosis (disorder)'),
#  ('Gen', 'General examination of patient (procedure)'),
#  ('Awake', 'Awake (finding)'),
#  ('alert', 'Mentally alert (finding)'),
#  ('NAD', 'No abnormality detected (finding)'),
#  ('CV', 'Cardiovascular physical examination (procedure)'),
#  ('RRR', 'Normal heart rate (finding)'),
#  ('Chest', 'Examination of respiratory system (procedure)'),
#  ('incisions', 'Surgical incision wound (morphologic abnormality)'),
#  ('dressing', 'Application of dressing (procedure)'),
#  ('Resp', 'Examination of respiratory system (procedure)'),
#  ('WOB', 'Labored breathing (finding)'),
#  ('distress', 'Distress (finding)'),
#  ('NC', 'Normal head (finding)'),
#  ('CTAB', 'Normal breath sounds (finding)'),
#  ('wheezes', 'Wheezing (finding)'),
#  ('crackles', 'Respiratory crackles (finding)'),
#  ('Abdomen', 'Examination of abdomen (procedure)'),
#  ('Soft', 'Abdomen soft (finding)'),
#  ('non-distended', 'Normal abdominal contour (finding)'),
#  ('TTP', 'Tenderness (finding)'),
#  ('Ext', 'Examination of limb (procedure)'),
#  ('Warm', 'Warm skin (finding)'),
#  ('well-perfused', 'Normal tissue perfusion (finding)'),
#  ('Liver', 'Liver structure (body structure)'),
#  ('Doppler US', 'Doppler ultrasonography (procedure)'),
#  ('transplant', 'Structure of transplant (body structure)'),
#  ('hepatic vasculature', 'Vascular structure of liver (body structure)'),
#  ('transplant', 'Structure of transplant (body structure)'),
#  ('liver', 'Liver structure (body structure)'),
#  ('biliary dilatation', 'Hypertrophy of bile duct (disorder)'),
#  ('left', 'Left lung structure (body structure)'),
#  ('pleural effusion', 'Pleural effusion (disorder)'),
#  ('GRAM STAIN', 'Gram stain method (procedure)'),
#  ('CULTURE', 'Microbial culture (procedure)'),
#  ('right upper lobectomy',
#   'Lobectomy of upper lobe of right lung (procedure)'),
#  ('flexible bronchoscopy', 'Flexible bronchoscopy (procedure)'),
#  ('extubated', 'Removal of endotracheal tube (procedure)'),
#  ('procedure', 'Procedure (procedure)'),
#  ('dyspneic', 'Dyspnea (finding)'),
#  ('moving minimal air', 'Difficulty breathing (finding)'),
#  ('reintubated', 'Intubation (procedure)'),
#  ('respiratory distress', 'Respiratory distress (finding)'),
#  ('Neuro', 'Neurology service (procedure)'),
#  ('chronic pain', 'Chronic pain (finding)'),
#  ('CV', 'Cardiovascular physical examination (procedure)'),
#  ('hypertension', 'Hypertensive disorder, systemic arterial (disorder)'),
#  ('hemodynamically stable', 'Hemodynamically stable (finding)'),
#  ('Pulm', 'Examination of respiratory system (procedure)'),
#  ('Respiratory distress', 'Respiratory distress (finding)'),
#  ('lung', 'Metastatic malignant neoplasm to lung (disorder)'),
#  ('contusion', 'Contusion (disorder)'),
#  ('pain', 'Abdominal pain (finding)'),
#  ('extubated', 'Removal of endotracheal tube (procedure)'),
#  ('bronchoscopies', 'Bronchoscopy (procedure)'),
#  ('CXR', 'Plain chest X-ray (procedure)'),
#  ('GI', 'Structure of digestive system (body structure)'),
#  ('Transplant', 'Transplantation (procedure)'),
#  ('liver transplant', 'Transplantation of liver (procedure)'),
#  ('LFTs', 'Hepatic function panel (procedure)'),
#  ('Liver', 'Liver structure (body structure)'),
#  ('elevated', 'Elevation (procedure)'),
#  ('LFTs', 'Hepatic function panel (procedure)'),
#  ('abnormalities', 'No abnormality detected (finding)'),
#  ('LFTs', 'Hepatic function panel (procedure)'),
#  ('transplant', 'Transplantation (procedure)'),
#  ('extubated', 'Removal of endotracheal tube (procedure)'),
#  ('diet', 'Dietary finding (finding)'),
#  ('regular diet', 'Normal diet (finding)'),
#  ('nausea / vomiting', 'Nausea and vomiting (disorder)'),
#  ('passing flatus', 'Passing flatus (finding)'),
#  ('GU', 'Examination of genitourinary system (procedure)'),
#  ('able to void', 'Normal micturition (finding)'),
#  ('foley removal', 'Removal of urinary bladder catheter (procedure)'),
#  ('CKD', 'Chronic kidney disease (disorder)'),
#  ('Heme', 'Hematology test (procedure)'),
#  ('H', 'Hemoglobin finding (finding)'),
#  ('stable', "Patient's condition stable (finding)"),
#  ('transfusions', 'Transfusion (procedure)'),
#  ('ID', 'Infectious disease (disorder)'),
#  ('physical therapy', 'Physical therapy procedure (regime/therapy)'),
#  ('hemodynamically stable', 'Hemodynamically stable (finding)'),
#  ('pain was well controlled', 'Demonstrates adequate pain control (finding)'),
#  ('oral medications',
#   'Administration of drug or medicament via oral route (procedure)'),
#  ('regular diet', 'Normal diet (finding)'),
#  ('ready for discharge', 'Ready for discharge (finding)'),
#  ('right upper lobe',
#   'Structure of upper lobe of right lung (body structure)'),
#  ('non-small cell lung cancer', 'Non-small cell lung cancer (disorder)'),
#  ('Mental Status', 'Neurological mental status determination (procedure)'),
#  ('Level of Consciousness', 'Assessment of consciousness level (procedure)'),
#  ('Alert', 'Mentally alert (finding)'),
#  ('Activity Status', 'Physical functional dependency (finding)'),
#  ('Ambulatory - Independent', 'Independent walking (finding)'),
#  ('lung', 'Lung structure (body structure)'),
#  ('surgery', 'Surgical procedure (procedure)'),
#  ('ready for discharge', 'Ready for discharge (finding)'),
#  ('incisions', 'Surgical incision wound (morphologic abnormality)'),
#  ('redness', 'Redness of skin over lesion (finding)'),
#  ('drainage', 'Discharge (morphologic abnormality)'),
#  ('draining', 'Discharge (morphologic abnormality)'),
#  ('removed', 'Removal of dressing (procedure)'),
#  ('drain', 'Discharge (morphologic abnormality)'),
#  ('dressing', 'Application of dressing (procedure)'),
#  ('pain medication', 'Administration of analgesic (procedure)'),
#  ('discomfort', 'Discomfort (finding)'),
#  ('pain medications', 'Administration of analgesic (procedure)'),
#  ('constipating', 'Constipation (finding)'),
#  ('problems', 'Problem (finding)'),
#  ('stool softener', 'Administration of laxative (procedure)'),
#  ('regular', 'Normal heart rate (finding)'),
#  ('while taking narcotic pain medication', 'Narcotics education (procedure)'),
#  ('incision', 'Surgical incision wound (morphologic abnormality)'),
#  ('incision', 'Surgical incision wound (morphologic abnormality)'),
#  ('Fevers', 'Fever (finding)'),
#  ('chills', 'Chill (finding)'),
#  ('shortness of breath', 'Dyspnea (finding)'),
#  ('chest pain', 'Chest pain (finding)')]

# %%
from tqdm import tqdm
from difflib import SequenceMatcher
import re
import pickle

# %%
def clean(text):
    '''
    Just a helper fuction to add a space before the punctuations for better tokenization
    '''
    filters = ["!", "#", "$", "%", "&", "(", ")", "/", "*", ".", ":", ";", "<", "=", ">", "?", "@", "[",
               "\\", "]", "_", "`", "{", "}", "~", "'"]
    for i in text:
        if i in filters:
            text = text.replace(i, " " + i)

    return text

# %%
def matcher(string, pattern):
    '''
    Return the start and end index of any pattern present in the text.
    '''
    match_list = []
    pattern = pattern.strip()
    seqMatch = SequenceMatcher(None, string, pattern, autojunk=False)
    match = seqMatch.find_longest_match(0, len(string), 0, len(pattern))
    if (match.size == len(pattern)):
        start = match.a
        end = match.a + match.size
        match_tup = (start, end)
        string = string.replace(pattern, "X" * len(pattern), 1)
        match_list.append(match_tup)
        # print(match_list)
    return match_list, string

# %%
# def mark_sentence(s, match_list):
#     '''
#     Marks all the entities in the sentence as per the BIO scheme.
#     '''
#     word_dict = []
#     for word in s.split():
#         word_dict[word] = 'O'

#     for start, end, e_type in match_list:
#         temp_str = s[start:end]
#         tmp_list = temp_str.split()
#         print(tmp_list)
#         if len(tmp_list) > 1:
#             word_dict[tmp_list[0]] = 'B-' + e_type
#             for w in tmp_list[1:]:
#                 word_dict[w] = 'I-' + e_type
#         else:
#             word_dict[temp_str] = 'B-' + e_type
#     return word_dict

# %%
def mark_sentence(text, match_list):
  l = text.split()
  for start, end, e_type in match_list:
    temp = text[start:end]
    # print(temp)
    temp_list = temp.split()
    # print(temp_list)
    n = len(temp_list)
    for i in range(len(l)):
      if(n==1):
        if(l[i]==temp_list[0]):
          l[i]='B-' + e_type
      else:
        flag = True
        for j in range(n):
          if (i+j)<len(l) and temp_list[j]!=l[i+j]:
            flag = False
            break
        if(flag):
          l[i] = 'B-' + e_type
          for k in range(1,n):
            if(i+k < len(l)):
              l[i+k] = 'I-' + e_type
  for i in range(len(l)):
    if((len(l[i])>1) and (l[i][0]=='B' or l[i][0]=='I') and l[i][1]=='-'):
      continue
    else:
      l[i]='O'
  return l

# %%
def create_data(df, filepath):
    '''
    The function responsible for the creation of data in the said format.
    '''
    df2 = pd.DataFrame(columns=['text', 'labels'])
    index = 1
    with open(filepath , 'w') as f:
        for text, annotation in zip(df.text, df.annotations):
            # text = clean(text)
            text_ = text
            # print(text)
            match_list = []
            # print(annotation)
            for i in annotation:
                # print(i)
                a, text_ = matcher(text, i[0])
                # print(a[0])
                match_list.append((a[0][0], a[0][1], i[1]))
            # print(match_list)

            d = mark_sentence(text, match_list)
            complete_string = ' '.join(d)
            data_to_append = {'text': text,
                  'labels': complete_string,}

            df2 = df2.append(pd.Series(data_to_append, name=index))
            index = index + 1



            for i in range(len(d)):
                f.writelines(text.split()[i] + ' ' + d[i] +'\n')
            f.writelines('\n')

    return df2

# %%
final_dataset = create_data(dataset_row_merged, "train/data.txt")
# Out:
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))
# <ipython-input-55-4f5ae8891ea9>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(pd.Series(data_to_append, name=index))

# %%
final_dataset.to_csv("NER_dataset.csv")

# %%
df_train = dataset_row_merged[:184]
df_test = dataset_row_merged[184:199]
df_dev = dataset_row_merged[199:]

create_data(df_train, "train/train.txt")
create_data(df_test, "train/test.txt")
create_data(df_dev, "train/dev.txt")

# %%
# !pip3 install flair

# %%
# !pip3 install --upgrade urllib3

# %%
from flair.data import Corpus
from flair.datasets import ColumnCorpus

# define columns
columns = {0 : 'text', 1 : 'ner'}
# directory where the data resides
data_folder = 'train'
# initializing the corpus
corpus: Corpus = ColumnCorpus(data_folder, columns,
                              train_file = 'train.txt',
                              test_file = 'test.txt',
                              dev_file = 'dev.txt')

# %%
print(len(corpus.train))

# %%
print(corpus.train[0].to_tagged_string('ner'))

# %%
# tag to predict
tag_type = 'ner'
# make tag dictionary from the corpus
tag_dictionary = corpus.make_tag_dictionary(tag_type=tag_type)

# %%
from flair.embeddings import WordEmbeddings, StackedEmbeddings
from flair.embeddings import TokenEmbeddings
from typing import List
embedding_types : List[TokenEmbeddings] = [
        WordEmbeddings('glove'),
        ## other embeddings
        ]
embeddings : StackedEmbeddings = StackedEmbeddings(
                                 embeddings=embedding_types)

# %%
from flair.models import SequenceTagger
tagger : SequenceTagger = SequenceTagger(hidden_size=256,
                                       embeddings=embeddings,
                                       tag_dictionary=tag_dictionary,
                                       tag_type=tag_type,
                                       use_crf=True)
print(tagger)

# %%
from flair.trainers import ModelTrainer
trainer : ModelTrainer = ModelTrainer(tagger, corpus)
trainer.train('resources/taggers/example-ner',
              learning_rate=0.0001,
              mini_batch_size=4,
              max_epochs=150)

# %%
from flair.data import Sentence
from flair.models import SequenceTagger
# load the trained model
model = SequenceTagger.load('/content/resources/taggers/example-ner/final-model.pt')
# create example sentence
sentence = Sentence('Service: CARDIOTHORACIC\n \nAllergies: \nCodeine / Quinine\n \nAttending: ___\n \nChief Complaint:\nnon-small cell lung cancer\n \nMajor Surgical or Invasive Procedure:\nvideo assisted cervical mediastinoscopy, flexible bronchoscopy\n\n \nHistory of Present Illness:\nMr. ___ is a ___ current ___ py smoker, hx Hep C & HCC s/p\nliver transplant ___, with 3cm RUL PET-avid nodule with\npathology showing non-small cell carcinoma, here for follow-up.\n\nHe has been asymptomatic since previous visit. No SOB, cough. No\nfevers, chills, nightsweats. He had EBUS which biopsied lesion\nshowing non-small cell carcinoma. Lymph nodes were not biopsied. \n\nPET negative for distant metastasis.\n \nPast Medical History:\nHEPATITIS C (genotype 1a, no sequelae of chronic liver disease \nat this point, stage III fibrosis on biopsy; now s/p liver \ntransplant)\nHEPATOCELLULAR CARCINOMA (s/p RFA on ___ to segment VIa \nlesion; now s/p liver transplant)')
# predict the tags
model.predict(sentence)
print(sentence.to_tagged_string())

# %%
from flair.embeddings import TransformerWordEmbeddings
from flair.models import SequenceTagger
from flair.trainers import ModelTrainer

# %%
label_type = 'ner'
label_dict = corpus.make_label_dictionary(label_type=label_type, add_unk=False)
print(label_dict)

# %%
embeddings = TransformerWordEmbeddings(model='xlm-roberta-large',
                                       layers="-1",
                                       subtoken_pooling="first",
                                       fine_tune=True,
                                       use_context=True,
                                       )

# %%
tagger = SequenceTagger(hidden_size=256,
                        embeddings=embeddings,
                        tag_dictionary=label_dict,
                        tag_type='ner',
                        use_crf=False,
                        use_rnn=False,
                        reproject_embeddings=False,
                        )

# %%
trainer = ModelTrainer(tagger, corpus)

# %%
trainer.fine_tune('resources/taggers/sota-ner-flert',
                  learning_rate=5.0e-6,
                  mini_batch_size=1,
                  mini_batch_chunk_size=1,  # remove this parameter to speed up computation if you have a big GPU
                  )
